# %%
import pandas as pd
import numpy as np

# %%
csv_data = pd.read_csv('Salaries.csv')
df = pd.DataFrame(csv_data)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# ## How many job title were represented by only one person in 2013 ? (Eg. Job Titles with only one occurence in 2013 )

# %%
jobs_in_2013 = df.loc[(df.Year == 2013)] 
jobs_in_2013[['JobTitle','Year']]
unique_jobs_in_2013 = jobs_in_2013['JobTitle'].unique()

count = 0
for i in unique_jobs_in_2013:
    count +=1
    print(i,count)
    
print('\n')
print("There are ",count, "unique jobs in 2013 ! ")
    
no_of_jobs = np.size(unique_jobs_in_2013)
# Out:
# Chief of Police 1
# Chief, Fire Department 2
# Battalion Chief, Fire Suppress 3
# Asst Med Examiner 4
# Dep Dir for Investments, Ret 5
# Asst Chf of Dept (Fire Dept) 6
# Executive Contract Employee 7
# Dept Head V 8
# Gen Mgr, Public Trnsp Dept 9
# Senior Physician Specialist 10
# Deputy Chief 3 11
# Dep Chf of Dept (Fire Dept) 12
# Lieutenant, Fire Suppression 13
# Mayor 14
# Assistant Deputy Chief 2 15
# Adm, SFGH Medical Center 16
# Captain, Fire Suppression 17
# Controller 18
# Deputy Sheriff 19
# Anesthetist 20
# EMT/Paramedic/Firefighter 21
# Inspector 3 22
# Port Director 23
# Emergency Medical Svcs Chief 24
# Dep Dir V 25
# Lieutenant 3 26
# Deputy Dir II, MTA 27
# Commander 3 28
# Incident Support Specialist 29
# Nursing Supervisor 30
# District Attorney 31
# Captain, Emergency Med Svcs 32
# Firefighter 33
# Manager VIII 34
# City Attorney 35
# Dept Head IV 36
# Lieut,Fire Prev 37
# Police Officer 2 38
# Police Officer 39
# Sheriff (SFERS) 40
# Administrator, DPH 41
# ...

# %% [markdown]
# ###  Check the head of the dataFrame

# %%
sal = pd.read_csv('Salaries.csv')
sal.head(2)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN

# %% [markdown]
# #### Use .info() method to find how many entities there are

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# #### What is the average of BasePay?

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# ### What is the highest amount of OvertimePay in dataset ?

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# #### What is the JobTitle of JOSEPH DRISCOLL?

# %%
# 1st method:
jd = sal.loc[sal['EmployeeName'] == 'JOSEPH DRISCOLL'] 
jd.JobTitle
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
# alternative method :

sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL'].JobTitle
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ### How much JOSEPH DRISCOLL make ? (including benefits)

# %%
jd = sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
#jd.TotalPayBenefits       --> alternative way 
jd
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ### what is the name of highest paid person including benefits ?

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
sal[sal['TotalPayBenefits'] == 567595.43]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
## alternative method using loc function :
sal.iloc[sal['TotalPayBenefits'].argmax()]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %%
sal.loc[sal['TotalPayBenefits'].idxmax()]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %% [markdown]
# ### what is the name of the lowest paid person including benefits?

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
sal.loc[sal['TotalPayBenefits'].argmin()]
# Out:
# Id                                      148654
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                    0.0
# OvertimePay                                0.0
# OtherPay                               -618.13
# Benefits                                   0.0
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Notes                                      NaN
# Agency                           San Francisco
# Status                                     NaN
# Name: 148653, dtype: object

# %% [markdown]
# ### What was the average BasePay of all employees per year (2011-2014)?

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ### How many unique job tile are there ?

# %%
len(sal['JobTitle'].unique())

# or you can use nunique()
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# ## What are the top 5 most common jobs?

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ### How many job titles were represented by only one person in 2013? (JobTitles with only one occurance in 2013)

# %%
sum(sal[sal['Year'] == 2013]['JobTitle'].value_counts() == 1)
# Out:
# 202

# %% [markdown]
# ### How many people have the word Chief in their JobTitle?

# %%
def chief_string(title):
    if 'chief' in title.lower().split():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda x : chief_string(x)))
# Out:
# 477

# %%
#alteratively :

sal[sal['JobTitle'].apply(lambda x : chief_string(x))]['JobTitle'].count()
# Out:
# 477

# %% [markdown]
# ### Is there a corelation between length of the JobTitle string and salry ?

# %%
sal['title_len'] = sal['JobTitle'].apply(len)

sal[['title_len','TotalPayBenefits']].corr()
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000
